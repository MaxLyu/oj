# %%
import pandas as pd
import xlrd

# %%
data = pd.read_excel("../onlineJudge/onlineJudge/oj.xlsx")

# %%
data.describe()
# Out:
#                编号          提交量         正确数         正确率
# count  545.000000   545.000000  545.000000  545.000000
# mean   337.348624    73.214679   30.965138    0.384372
# std    206.646507   132.624109   54.566277    0.320557
# min      1.000000     0.000000    0.000000    0.000000
# 25%    163.000000     1.000000    0.000000    0.000000
# 50%    303.000000    18.000000    8.000000    0.368900
# 75%    538.000000    88.000000   37.000000    0.600000
# max    684.000000  1347.000000  367.000000    1.000000

# %%
data = data.set_index('编号')
data.head()
# Out:
#                                   标题  难度   提交量  正确数     正确率
# 编号
# 1                             2^k进制数  中等   154   52  0.3377
# 4                              马拦过河卒  中等   159   74  0.4654
# 5                                产生数  困难   236   22  0.0932
# 6                             【排队买票】  简单   342  148  0.4327
# 7   【C语言训练】求s=a+aa+aaa+aaaa+aa...a的值  困难  1347  329  0.2442

# %%
rate = data['正确率']

# %%
data[data['正确率'] == max(rate)]     # 正确率最大的题目数据
# Out:
#               标题  难度  提交量  正确数  正确率
# 编号
# 33      【作业调度方案】  中等    5    5  1.0
# 90           小教官  中等    2    2  1.0
# 106      Jam的计数法  中等    8    8  1.0
# 147        二叉树问题  中等    7    7  1.0
# 160        阻击火箭队  中等    1    1  1.0
# 173       可恶的雾霾天  中等    1    1  1.0
# 220      继续xxx定律  中等    3    3  1.0
# 226       最短路径问题  中等    1    1  1.0
# 245   算法3-7：银行排队  中等    3    3  1.0
# 262      奥运排序问题   中等    1    1  1.0
# 269        最大报销额  中等    1    1  1.0
# 270         游船出租  中等    1    1  1.0
# 275      确定比赛名次   中等    1    1  1.0
# 278         Tr A  中等    1    1  1.0
# 280        产生冠军   中等    1    1  1.0
# 287       二叉树の狂欢  中等    1    1  1.0
# 288         隐匿行踪  中等    1    1  1.0
# 303       王国的成熟度  中等    1    1  1.0
# 306          果冻豆  中等    1    1  1.0
# 308         旅游景点  中等    2    2  1.0
# 311          反着来  中等    1    1  1.0
# 318     班级聚会上的游戏  中等    2    2  1.0
# 319          拼火柴  中等    2    2  1.0
# 322       买不到的数目  中等    2    2  1.0
# 324          幸运数  中等    1    1  1.0
# 348         公式求值  简单    1    1  1.0
# 375        校门外的树  中等    1    1  1.0
# 454        校门外的树  中等    2    2  1.0
# 455       JAM计数法  中等    1    1  1.0
# 456         集合运算  中等    1    1  1.0
# 458         排列问题  中等    1    1  1.0
# 460         星际交流  中等    1    1  1.0
# 461  Hankson的趣味题  简单    1    1  1.0
# 463      连续正整数的和  中等    3    3  1.0
# 475       统计单词个数  中等    1    1  1.0
# 508        猴子分苹果  简单    2    2  1.0
# 512      Hanoi问题  困难    1    1  1.0
# 518         字母图形  困难    2    2  1.0
# 529         概率计算  困难    1    1  1.0
# 531     9-2 文本加密  困难    8    8  1.0
# 548          拿糖果  中等    1    1  1.0
# 555        学霸的迷宫  中等    2    2  1.0
# 558        简单计算器  困难   17   17  1.0
# 569         征税程序  中等   17   17  1.0
# 584          排列数  困难    3    3  1.0
# 600      盾神与条状项链  简单    2    2  1.0
# 631      未名湖边的烦恼  简单   14   14  1.0
# 670         结点选择  困难    1    1  1.0

# %%
data[data['正确率'] == min(rate)]     # 正确率最小的题目数据
# Out:
#                        标题  难度  提交量  正确数  正确率
# 编号
# 75                    独木桥  困难   31    0  0.0
# 80                     年会  中等    0    0  0.0
# 107                 破解平方数  中等    1    0  0.0
# 155             ACM俱乐部大聚会  中等    2    0  0.0
# 286            你们要的中缀表达式树  中等    5    0  0.0
# 293                   发奖金  中等    4    0  0.0
# 321                  兰顿蚂蚁  中等    0    0  0.0
# 323                  错误票据  困难    0    0  0.0
# 325                 小朋友排队  中等    0    0  0.0
# 326                  九宫重排  简单    0    0  0.0
# 327                   带分数  简单    0    0  0.0
# 329                  高僧斗法  困难    1    0  0.0
# 330                  车轮轴迹  简单    0    0  0.0
# 331                  最大子阵  简单    0    0  0.0
# 332                 国王的烦恼  简单    0    0  0.0
# 333                   剪格子  困难    0    0  0.0
# 334                  蚂蚁感冒  困难    1    0  0.0
# 336                 格子刷油漆  简单    0    0  0.0
# 337                  波动数列  简单    0    0  0.0
# 339                 连号区间数  困难    0    0  0.0
# 340                   分糖果  简单    0    0  0.0
# 341               约数倍数选卡片  困难    0    0  0.0
# 342                  农场阳光  简单    0    0  0.0
# 343                 大臣的旅费  简单    0    0  0.0
# 344                  数字游戏  困难    1    0  0.0
# 345                  网络寻路  中等    0    0  0.0
# 346               横向打印二叉树  简单    0    0  0.0
# 347                  危险系数  简单    0    0  0.0
# 349                    邮局  简单    0    0  0.0
# 350                 矩阵翻硬币  困难    0    0  0.0
# ..                    ...  ..  ...  ...  ...
# 622              Bus Tour  简单    0    0  0.0
# 625    Collecting Luggage  简单    0    0  0.0
# 627    Pollution Solution  简单    0    0  0.0
# 628                   逆序对  困难    0    0  0.0
# 632        Lift and Throw  中等    0    0  0.0
# 633  The Ministers  Major  困难    0    0  0.0
# 634  Air Conditioning Mac  简单    0    0  0.0
# 636       A Major Problem  困难    0    0  0.0
# 641  Consanguine Calculat  困难    0    0  0.0
# 642            Partitions  中等    0    0  0.0
# 643         Eurodiffusion  困难    0    0  0.0
# 647      Tiling the Plane  困难    0    0  0.0
# 648   Beaver s Calculator  简单    0    0  0.0
# 650                  操作格子  困难    0    0  0.0
# 651     Balloons in a Box  困难    0    0  0.0
# 652                 最大的算式  困难    0    0  0.0
# 653   Crossing the Desert  困难    0    0  0.0
# 655               Cowboys  中等    0    0  0.0
# 656  According to Bartjen  中等    0    0  0.0
# 657           C++ CH08 01  困难    0    0  0.0
# 660  Don t fear, DravDe i  简单    0    0  0.0
# 662  The Traveling Judges  简单    0    0  0.0
# 666          infiltration  简单    0    0  0.0
# 667                  关联矩阵  困难    5    0  0.0
# 672  Entertaining Geodeti  中等    0    0  0.0
# 675              Матрёшка  简单    0    0  0.0
# 676                  安慰奶牛  中等    0    0  0.0
# 681      A Linking Loader  困难    0    0  0.0
# 683  Tricky and Clever Pa  简单    3    0  0.0
# 684              Pyramids  困难    0    0  0.0
#
# [138 rows x 5 columns]

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
import matplotlib.style as psl
psl.use('seaborn-colorblind')    # 设置图表风格
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签

# %%
level_values = data['难度'].values

difficulties = {
    '简单': 0,
    '中等': 0,
    '困难': 0
}

for value in level_values:
    if value == '简单':
        difficulties['简单'] += 1
    elif value == '中等':
        difficulties['中等'] += 1
    else:
        difficulties['困难'] += 1

level = pd.Series(difficulties)
print(level)

level.plot(kind = 'bar', figsize=(6, 7))
plt.grid(axis='y')
#fig, axes = plt.subplots(figsize=(6, 8))
#axes.bar(xValue, yValue, align="center")
# Out:
# 中等    231
# 困难    134
# 简单    180
# dtype: int64

# %%
relation = data[['难度', '正确率']]
relation
# Out:
#      难度     正确率
# 编号
# 1    中等  0.3377
# 4    中等  0.4654
# 5    困难  0.0932
# 6    简单  0.4327
# 7    困难  0.2442
# 9    中等  0.3202
# 10   简单  0.4185
# 11   简单  0.5529
# 12   简单  0.5943
# 15   简单  0.4615
# 16   中等  0.3941
# 17   简单  0.5467
# 18   简单  0.7447
# 19   中等  0.8333
# 20   中等  0.4660
# 21   中等  0.3531
# 23   中等  0.4482
# 24   困难  0.0345
# 25   中等  0.5410
# 26   中等  0.3571
# 27   中等  0.5391
# 28   中等  0.3689
# 29   中等  0.5050
# 31   简单  0.4340
# 32   困难  0.2602
# 33   中等  1.0000
# 35   简单  0.6182
# 36   中等  0.2760
# 38   中等  0.4766
# 39   中等  0.4131
# ..   ..     ...
# 649  简单  0.6000
# 650  困难  0.0000
# 651  困难  0.0000
# 652  困难  0.0000
# 653  困难  0.0000
# 654  困难  0.6711
# 655  中等  0.0000
# 656  中等  0.0000
# 657  困难  0.0000
# 659  中等  0.7500
# 660  简单  0.0000
# 661  困难  0.6000
# 662  简单  0.0000
# 663  中等  0.6163
# 666  简单  0.0000
# 667  困难  0.0000
# 669  中等  0.3333
# 670  困难  1.0000
# 671  困难  0.3462
# 672  中等  0.0000
# 674  困难  0.5965
# 675  简单  0.0000
# 676  中等  0.0000
# 677  简单  0.6591
# 679  中等  0.4815
# 680  中等  0.7778
# 681  困难  0.0000
# 682  困难  0.4688
# 683  简单  0.0000
# 684  困难  0.0000
#
# [545 rows x 2 columns]

# %%
import numpy as np

rate_values = relation['正确率'].values

fig, axes = plt.subplots(figsize=(15, 6))
axes.scatter(rate_values, level_values)
plt.grid(axis='x')
plt.xticks(np.arange(0, 1, 0.05))
plt.xlabel('正确率')
plt.ylabel('难度')
# Out:
# Text(0,0.5,'难度')
